# %% [markdown]
# # Clustering the Countries by using K-Means for HELP International #
#
#
# ## Objective: ##
# Untuk mengkategorikan negara menggunakan faktor sosial ekonomi dan kesehatan yang menentukan pembangunan negara secara keseluruhan.
#
# ## Tentang Organisasi: ##
# HELP International adalah LSM kemanusiaan internasional yang berkomitmen untuk memerangi kemiskinan dan menyediakan fasilitas dan bantuan dasar bagi masyarakat di negara-negara terbelakang saat terjadi bencana dan bencana alam.
#
# ## Permasalahan: ##
# HELP International telah berhasil mengumpulkan sekitar $ 10 juta. Saat ini, CEO LSM perlu memutuskan bagaimana menggunakan uang ini secara strategis dan efektif. Jadi, CEO harus mengambil keputusan untuk memilih negara yang paling membutuhkan bantuan. Oleh karena itu, Tugas teman-teman  adalah mengkategorikan negara menggunakan beberapa faktor sosial ekonomi dan kesehatan yang menentukan perkembangan negara secara keseluruhan. Kemudian kalian perlu menyarankan negara mana saja  yang paling perlu menjadi fokus CEO.

# %%
# !pip install -U seaborn
# Out:
# ...
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.10.1
#     Uninstalling seaborn-0.10.1:
#       Successfully uninstalled seaborn-0.10.1
# ...

# %%
# Preparation Library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display

# %%
# Preparation File
path = r'C:\Users\David Yohast\Downloads\2021-06 Bootcamp Sanbercode\Final Project\Data_Negara_HELP.csv'
df = pd.read_csv(path)
df
# Out:
#                   Negara  Kematian_anak  Ekspor  Kesehatan  Impor  Pendapatan  \
# 0            Afghanistan           90.2    10.0       7.58   44.9        1610
# 1                Albania           16.6    28.0       6.55   48.6        9930
# 2                Algeria           27.3    38.4       4.17   31.4       12900
# 3                 Angola          119.0    62.3       2.85   42.9        5900
# 4    Antigua and Barbuda           10.3    45.5       6.03   58.9       19100
# ..                   ...            ...     ...        ...    ...         ...
# 162              Vanuatu           29.2    46.6       5.25   52.7        2950
# 163            Venezuela           17.1    28.5       4.91   17.6       16500
# 164              Vietnam           23.3    72.0       6.84   80.2        4490
# 165                Yemen           56.3    30.0       5.18   34.4        4480
# 166               Zambia           83.1    37.0       5.89   30.9        3280
#
# ...

# %%
df.isnull().sum()
# Out:
# Negara              0
# Kematian_anak       0
# Ekspor              0
# Kesehatan           0
# Impor               0
# Pendapatan          0
# Inflasi             0
# Harapan_hidup       0
# Jumlah_fertiliti    0
# GDPperkapita        0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167 entries, 0 to 166
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Negara            167 non-null    object
#  1   Kematian_anak     167 non-null    float64
#  2   Ekspor            167 non-null    float64
#  3   Kesehatan         167 non-null    float64
#  4   Impor             167 non-null    float64
#  5   Pendapatan        167 non-null    int64
#  6   Inflasi           167 non-null    float64
#  7   Harapan_hidup     167 non-null    float64
#  8   Jumlah_fertiliti  167 non-null    float64
#  9   GDPperkapita      167 non-null    int64
# dtypes: float64(7), int64(2), object(1)
# memory usage: 12.5+ KB

# %%
sns.set(style="ticks", context="talk")
plt.style.use("dark_background")

# %%
sns.histplot(data=df, x='Kematian_anak');
print(df['Kematian_anak'].describe())
# Out:
# count    167.000000
# mean      38.270060
# std       40.328931
# min        2.600000
# 25%        8.250000
# 50%       19.300000
# 75%       62.100000
# max      208.000000
# Name: Kematian_anak, dtype: float64

# %%
sns.histplot(data=df, x='Ekspor');
print(df['Ekspor'].describe())
# Out:
# count    167.000000
# mean      41.108976
# std       27.412010
# min        0.109000
# 25%       23.800000
# 50%       35.000000
# 75%       51.350000
# max      200.000000
# Name: Ekspor, dtype: float64

# %%
sns.histplot(data=df, x='Kesehatan');
print(df['Kesehatan'].describe())
# Out:
# count    167.000000
# mean       6.815689
# std        2.746837
# min        1.810000
# 25%        4.920000
# 50%        6.320000
# 75%        8.600000
# max       17.900000
# Name: Kesehatan, dtype: float64

# %%
sns.histplot(data=df, x='Impor');
print(df['Impor'].describe())
# Out:
# count    167.000000
# mean      46.890215
# std       24.209589
# min        0.065900
# 25%       30.200000
# 50%       43.300000
# 75%       58.750000
# max      174.000000
# Name: Impor, dtype: float64

# %%
sns.histplot(data=df, x='Pendapatan');
print(df['Pendapatan'].describe())
# Out:
# count       167.000000
# mean      17144.688623
# std       19278.067698
# min         609.000000
# 25%        3355.000000
# 50%        9960.000000
# 75%       22800.000000
# max      125000.000000
# Name: Pendapatan, dtype: float64

# %%
sns.histplot(data=df, x='Inflasi');
print(df['Inflasi'].describe())
# Out:
# count    167.000000
# mean       7.781832
# std       10.570704
# min       -4.210000
# 25%        1.810000
# 50%        5.390000
# 75%       10.750000
# max      104.000000
# Name: Inflasi, dtype: float64

# %%
sns.histplot(data=df, x='Harapan_hidup');
print(df['Harapan_hidup'].describe())
# Out:
# count    167.000000
# mean      70.555689
# std        8.893172
# min       32.100000
# 25%       65.300000
# 50%       73.100000
# 75%       76.800000
# max       82.800000
# Name: Harapan_hidup, dtype: float64

# %%
sns.histplot(data=df, x='Jumlah_fertiliti');
print(df['Jumlah_fertiliti'].describe())
# Out:
# count    167.000000
# mean       2.947964
# std        1.513848
# min        1.150000
# 25%        1.795000
# 50%        2.410000
# 75%        3.880000
# max        7.490000
# Name: Jumlah_fertiliti, dtype: float64

# %%
sns.histplot(data=df, x='GDPperkapita');
print(df['GDPperkapita'].describe())
# Out:
# count       167.000000
# mean      12964.155689
# std       18328.704809
# min         231.000000
# 25%        1330.000000
# 50%        4660.000000
# 75%       14050.000000
# max      105000.000000
# Name: GDPperkapita, dtype: float64

# %%
# Check pairplot
sns.pairplot(df, corner=True);

# %% [markdown]
# ## GDP dan Kesehatan ##

# %%
df2 = df[['Negara','GDPperkapita','Kesehatan']]
df2
# Out:
#                   Negara  GDPperkapita  Kesehatan
# 0            Afghanistan           553       7.58
# 1                Albania          4090       6.55
# 2                Algeria          4460       4.17
# 3                 Angola          3530       2.85
# 4    Antigua and Barbuda         12200       6.03
# ..                   ...           ...        ...
# 162              Vanuatu          2970       5.25
# 163            Venezuela         13500       4.91
# 164              Vietnam          1310       6.84
# 165                Yemen          1310       5.18
# 166               Zambia          1460       5.89
#
# [167 rows x 3 columns]

# %%
sns.scatterplot(data=df2, x='GDPperkapita', y='Kesehatan');

# %% [markdown]
# ### Handling Outliers ###

# %%
#definisikan rumus mencari outliers
def lower_upper_limit(x):
    x75 = np.percentile(x, 75)
    x25 = np.percentile(x, 25)
    iqr = x75-x25
    lower_lim = x25 - (1.5 * iqr)
    upper_lim = x75 + (1.5 * iqr)
    return lower_lim, upper_lim

def outliers(x):
    batas_bawah, batas_atas = lower_upper_limit(x)
    return x[np.where(
    (x < batas_bawah) | 
    (x > batas_atas))]

# %%
# Outliers GDP
print('Outliers GDP adalah: ', outliers(df2['GDPperkapita'].values))

# Outliers Kesehatan
print('\nOutliers Kesehatan adalah: ', outliers(df2['Kesehatan'].values))
# Out:
# Outliers GDP adalah:  [ 51900  46900  44400  35300  47400  58000  46200  40600  41800  41900
#   48700  35800  44500  38500 105000  50300  33700  87800  70300  46600
#   52100  74600  35000  38900  48400]
#
# Outliers Kesehatan adalah:  [14.2 17.9]

# %%
# BB BA GDP
bb, ba = lower_upper_limit(df2['GDPperkapita'])
print(bb, ba, sep=' ')

# BB BA Kesehatan
bb1, ba1 = lower_upper_limit(df2['Kesehatan'])
print(bb1, ba1, sep=' ')
# Out:
# -17750.0 33130.0
# -0.6000000000000023 14.120000000000005

# %%
# Negara yang bisa dikecualikan
gdp_outliers_atas = df2['GDPperkapita'] > ba
kes_outliers_atas = df2['Kesehatan'] > ba1

df2_gdpout = df2[(gdp_outliers_atas | kes_outliers_atas)]
#df2_gdpout = df2_gdpout['Negara'].to_list()
df2_gdpout
# Out:
#                     Negara  GDPperkapita  Kesehatan
# 7                Australia         51900       8.73
# 8                  Austria         46900      11.00
# 15                 Belgium         44400      10.70
# 23                  Brunei         35300       2.84
# 29                  Canada         47400      11.30
# 44                 Denmark         58000      11.40
# 53                 Finland         46200       8.95
# 54                  France         40600      11.90
# 58                 Germany         41800      11.60
# 68                 Iceland         41900       9.40
# 73                 Ireland         48700       9.19
# 75                   Italy         35800       9.53
# 77                   Japan         44500       9.49
# 82                  Kuwait         38500       2.63
# 91              Luxembourg        105000       7.77
# 101  Micronesia, Fed. Sts.          2860      14.20
# 110            Netherlands         50300      11.90
# ...

# %%
df2_gdpout.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26 entries, 7 to 159
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Negara        26 non-null     object
#  1   GDPperkapita  26 non-null     int64
#  2   Kesehatan     26 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 728.0+ bytes

# %%
# DF tanpa outliers:
gdp_normal = df2['GDPperkapita'] < ba
kes_normal = df2['Kesehatan'] < ba1

df2_normal = df2[(gdp_normal & kes_normal)]
#df2_gdpout = df2_gdpout['Negara'].to_list()
df2_normal
# Out:
#                   Negara  GDPperkapita  Kesehatan
# 0            Afghanistan           553       7.58
# 1                Albania          4090       6.55
# 2                Algeria          4460       4.17
# 3                 Angola          3530       2.85
# 4    Antigua and Barbuda         12200       6.03
# ..                   ...           ...        ...
# 162              Vanuatu          2970       5.25
# 163            Venezuela         13500       4.91
# 164              Vietnam          1310       6.84
# 165                Yemen          1310       5.18
# 166               Zambia          1460       5.89
#
# [141 rows x 3 columns]

# %%
df2_normal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 141 entries, 0 to 166
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Negara        141 non-null    object
#  1   GDPperkapita  141 non-null    int64
#  2   Kesehatan     141 non-null    float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 3.9+ KB

# %%
sns.boxplot(data=df2_normal, x='GDPperkapita');

# %%
sns.boxplot(data=df2_normal, x='Kesehatan');

# %% [markdown]
# Karena masih ada outliers, maka data dihitung kembali untuk eliminasi outliers

# %%
df3 = df2_normal.copy()
# Outliers GDP
print('Outliers GDP adalah: ', outliers(df3['GDPperkapita'].values))

# Outliers Kesehatan
print('\nOutliers Kesehatan adalah: ', outliers(df3['Kesehatan'].values))
# Out:
# Outliers GDP adalah:  [28000 20700 30800 26900 30600 21100 22500 23400 22100 30700]
#
# Outliers Kesehatan adalah:  [13.1]

# %%
# BB BA GDP
bb, ba = lower_upper_limit(df3['GDPperkapita'])
print(bb, ba, sep=' ')

# BB BA Kesehatan
bb1, ba1 = lower_upper_limit(df3['Kesehatan'])
print(bb1, ba1, sep=' ')
# Out:
# -10125.0 20075.0
# 0.33000000000000096 12.41

# %%
# Negara yang bisa dikecualikan
gdp_outliers_atas = df3['GDPperkapita'] > ba
kes_outliers_atas = df3['Kesehatan'] > ba1

df3_out = df3[(gdp_outliers_atas | kes_outliers_atas)]
#df2_gdpout = df2_gdpout['Negara'].to_list()
df3_out
# Out:
#            Negara  GDPperkapita  Kesehatan
# 10        Bahamas         28000       7.89
# 11        Bahrain         20700       4.97
# 42         Cyprus         30800       5.97
# 60         Greece         26900      10.30
# 74         Israel         30600       7.63
# 98          Malta         21100       8.65
# 122      Portugal         22500      11.00
# 132  Sierra Leone           399      13.10
# 135      Slovenia         23400       9.41
# 138   South Korea         22100       6.93
# 139         Spain         30700       9.54

# %%
# DF tanpa outliers:
gdp_normal = df3['GDPperkapita'] < ba
kes_normal = df3['Kesehatan'] < ba1

df3_normal = df3[(gdp_normal & kes_normal)]
#df2_gdpout = df2_gdpout['Negara'].to_list()
df3_normal
# Out:
#                   Negara  GDPperkapita  Kesehatan
# 0            Afghanistan           553       7.58
# 1                Albania          4090       6.55
# 2                Algeria          4460       4.17
# 3                 Angola          3530       2.85
# 4    Antigua and Barbuda         12200       6.03
# ..                   ...           ...        ...
# 162              Vanuatu          2970       5.25
# 163            Venezuela         13500       4.91
# 164              Vietnam          1310       6.84
# 165                Yemen          1310       5.18
# 166               Zambia          1460       5.89
#
# [130 rows x 3 columns]

# %%
sns.boxplot(data=df3_normal, x='GDPperkapita');

# %%
sns.boxplot(data=df3_normal, x='Kesehatan');

# %% [markdown]
# Outliers masih muncul di GDP, maka GDP dihitung ulang

# %%
df4 = df3_normal.copy()
# Outliers GDP
print('Outliers GDP adalah: ', outliers(df4['GDPperkapita'].values))
# Out:
# Outliers GDP adalah:  [19800 17100 19300 19300 16600]

# %%
# BB BA GDP
bb, ba = lower_upper_limit(df4['GDPperkapita'])
print(bb, ba, sep=' ')
# Out:
# -7983.75 16366.25

# %%
# Negara yang bisa dikecualikan
gdp_outliers_atas = df4['GDPperkapita'] > ba

df4_out = df4[(gdp_outliers_atas)]
#df2_gdpout = df2_gdpout['Negara'].to_list()
df4_out
# Out:
#                 Negara  GDPperkapita  Kesehatan
# 43      Czech Republic         19800       7.88
# 49   Equatorial Guinea         17100       4.48
# 115               Oman         19300       2.77
# 128       Saudi Arabia         19300       4.29
# 134    Slovak Republic         16600       8.79

# %%
# DF tanpa outliers:
gdp_normal = df4['GDPperkapita'] < ba

df4_normal = df4[(gdp_normal)]
#df2_gdpout = df2_gdpout['Negara'].to_list()
df4_normal
# Out:
#                   Negara  GDPperkapita  Kesehatan
# 0            Afghanistan           553       7.58
# 1                Albania          4090       6.55
# 2                Algeria          4460       4.17
# 3                 Angola          3530       2.85
# 4    Antigua and Barbuda         12200       6.03
# ..                   ...           ...        ...
# 162              Vanuatu          2970       5.25
# 163            Venezuela         13500       4.91
# 164              Vietnam          1310       6.84
# 165                Yemen          1310       5.18
# 166               Zambia          1460       5.89
#
# [125 rows x 3 columns]

# %%
sns.boxplot(data=df4_normal, x='GDPperkapita');

# %%
df5 = df4_normal.copy()
# Outliers GDP
print('Outliers GDP adalah: ', outliers(df5['GDPperkapita'].values))
# Out:
# Outliers GDP adalah:  [16000]

# %%
# BB BA GDP
bb, ba = lower_upper_limit(df5['GDPperkapita'])
print(bb, ba, sep=' ')
# Out:
# -7195.0 14765.0

# %%
# Negara yang bisa dikecualikan
gdp_outliers_atas = df5['GDPperkapita'] > ba

df5_out = df5[(gdp_outliers_atas)]
#df2_gdpout = df2_gdpout['Negara'].to_list()
df5_out
# Out:
#       Negara  GDPperkapita  Kesehatan
# 13  Barbados         16000       7.97

# %%
# DF tanpa outliers:
gdp_normal = df5['GDPperkapita'] < ba

df5_normal = df5[(gdp_normal)]
#df2_gdpout = df2_gdpout['Negara'].to_list()
df5_normal
# Out:
#                   Negara  GDPperkapita  Kesehatan
# 0            Afghanistan           553       7.58
# 1                Albania          4090       6.55
# 2                Algeria          4460       4.17
# 3                 Angola          3530       2.85
# 4    Antigua and Barbuda         12200       6.03
# ..                   ...           ...        ...
# 162              Vanuatu          2970       5.25
# 163            Venezuela         13500       4.91
# 164              Vietnam          1310       6.84
# 165                Yemen          1310       5.18
# 166               Zambia          1460       5.89
#
# [124 rows x 3 columns]

# %%
sns.boxplot(data=df5_normal, x='GDPperkapita');

# %%
df6 = df5_normal.copy()
# Outliers GDP
print('Outliers GDP adalah: ', outliers(df6['GDPperkapita'].values))

# BB BA GDP
bb, ba = lower_upper_limit(df6['GDPperkapita'])
print(bb, ba, sep=' ')

# Negara yang bisa dikecualikan
gdp_outliers_atas = df6['GDPperkapita'] > ba

df6_out = df6[(gdp_outliers_atas)]
#df2_gdpout = df2_gdpout['Negara'].to_list()
display(df6_out)

# DF tanpa outliers:
gdp_normal = df6['GDPperkapita'] < ba

df6_normal = df6[(gdp_normal)]
#df2_gdpout = df2_gdpout['Negara'].to_list()
display(df6_normal)
# Out:
# Outliers GDP adalah:  [14600]
# -7017.5 14442.5
#      Negara  GDPperkapita  Kesehatan
# 51  Estonia         14600       6.03
#                   Negara  GDPperkapita  Kesehatan
# 0            Afghanistan           553       7.58
# 1                Albania          4090       6.55
# 2                Algeria          4460       4.17
# 3                 Angola          3530       2.85
# 4    Antigua and Barbuda         12200       6.03
# ..                   ...           ...        ...
# 162              Vanuatu          2970       5.25
# 163            Venezuela         13500       4.91
# 164              Vietnam          1310       6.84
# 165                Yemen          1310       5.18
# 166               Zambia          1460       5.89
#
# [123 rows x 3 columns]

# %%
sns.boxplot(data=df6_normal, x='GDPperkapita');

# %% [markdown]
# Outlier sudah tidak ada, maka review GDP dan Kesehatan sebagai berikut

# %%
sns.histplot(data=df6_normal, x='GDPperkapita');
print(df6_normal['GDPperkapita'].describe())
# Out:
# count      123.000000
# mean      4208.577236
# std       3760.487442
# min        231.000000
# 25%       1020.000000
# 50%       3040.000000
# 75%       6300.000000
# max      13500.000000
# Name: GDPperkapita, dtype: float64

# %%
sns.histplot(data=df6_normal, x='Kesehatan');
print(df6_normal['Kesehatan'].describe())
# Out:
# count    123.000000
# mean       6.182195
# std        2.183105
# min        1.970000
# 25%        4.825000
# 50%        5.860000
# 75%        7.520000
# max       11.800000
# Name: Kesehatan, dtype: float64

# %%
sns.scatterplot(data=df6_normal, x='GDPperkapita', y='Kesehatan');

# %% [markdown]
# ### Scaling ###

# %%
# Data yang tanpa outliers ada di dataframe bernama df6_normal
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

df7 = df6_normal[['GDPperkapita','Kesehatan']]
sc= StandardScaler()
df7_scaled = sc.fit_transform(df7.astype('float'))
df7_scaled
# Out:
# array([[-9.76077860e-01,  6.42901625e-01],
#        [-3.16613785e-02,  1.69166925e-01],
#        [ 6.71325424e-02, -9.25482185e-01],
#        [-1.81187313e-01, -1.53259850e+00],
#        [ 2.13379456e+00, -7.00001071e-02],
#        [ 1.62647443e+00,  8.82068657e-01],
#        [-2.63960598e-01, -8.19696767e-01],
#        [ 4.35607166e-01, -1.38990597e-01],
#        [-9.21340687e-01, -1.22444098e+00],
#        [ 4.86339179e-01, -2.63173480e-01],
#        [ 3.50912707e-02, -4.51747486e-01],
#        [-9.21340687e-01, -9.57677747e-01],
#        [-5.41651619e-01, -4.51747486e-01],
#        [-5.95053738e-01, -6.17324662e-01],
#        [ 1.07184132e-01,  2.26187846e+00],
#        [ 5.71782571e-01,  9.74055977e-01],
#        [ 1.86678397e+00,  1.30061096e+00],
#        [ 7.02617763e-01,  3.16346638e-01],
#        [-9.70203627e-01,  2.56554880e-01],
#        [-1.06205527e+00,  2.49184676e+00],
#        [-9.13864391e-01, -2.30977917e-01],
#        [-7.73950838e-01, -4.83943048e-01],
# ...

# %%
kmeans = KMeans(n_clusters = 4, random_state = 50).fit(df7_scaled)
labels = kmeans.labels_

# %%
df8 = pd.DataFrame(data= df7_scaled, columns=['GDP', 'Kesehatan'])
df8['hasil_kmeans']= labels
df8
# Out:
#           GDP  Kesehatan  hasil_kmeans
# 0   -0.976078   0.642902             0
# 1   -0.031661   0.169167             0
# 2    0.067133  -0.925482             2
# 3   -0.181187  -1.532598             2
# 4    2.133795  -0.070000             3
# ..        ...        ...           ...
# 118 -0.330713  -0.428751             0
# 119  2.480908  -0.585129             3
# 120 -0.773951   0.302549             0
# 121 -0.773951  -0.460946             0
# 122 -0.733899  -0.134391             0
#
# [123 rows x 3 columns]

# %%
k1_x1 = df8.GDP[df8.hasil_kmeans == 0]
k1_y1 = df8.Kesehatan[df8.hasil_kmeans == 0]

k2_x1 = df8.GDP[df8.hasil_kmeans == 1]
k2_y1 = df8.Kesehatan[df8.hasil_kmeans == 1]

k3_x1 = df8.GDP[df8.hasil_kmeans == 2]
k3_y1 = df8.Kesehatan[df8.hasil_kmeans == 2]

k4_x1 = df8.GDP[df8.hasil_kmeans == 3]
k4_y1 = df8.Kesehatan[df8.hasil_kmeans == 3]

plt.subplots(figsize=(15,8))
plt.scatter(k1_x1, k1_y1, c='red', s=100, edgecolors='green', linestyle='-')
plt.scatter(k2_x1, k2_y1, c='blue', s=100, edgecolors='green', linestyle='-')
plt.scatter(k3_x1, k3_y1, c='yellow', s=100, edgecolors='green', linestyle='-')
plt.scatter(k4_x1, k4_y1, c='purple', s=100, edgecolors='green', linestyle='-')

centers = kmeans.cluster_centers_
plt.scatter(centers[:,0], centers[:,1], c='white', s=500)
plt.xlabel('GDP')
plt.ylabel('Kesehatan')
plt.show()

# %%
# Elbow_Method
wcss = []
for i in range(1,15):
    kmeans= KMeans(n_clusters= i, init='k-means++', random_state= 50)
    kmeans.fit(df7_scaled)
    wcss.append(kmeans.inertia_)

plt.subplots(figsize=(15,8))
plt.plot(range(1,15), wcss)
plt.title('Elbow Method')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.show()

# %% [markdown]
# ### MAKE NEW KMEAN BASED ON ELBOW METHOD'S SUGGESTION ###

# %%
kmeans2 = KMeans(n_clusters = 3, random_state = 50).fit(df7_scaled)
labels2 = kmeans2.labels_

# %%
df8 = pd.DataFrame(data= df7_scaled, columns=['GDP', 'Kesehatan'])
df8['hasil_kmeans']= labels2
df8
# Out:
#           GDP  Kesehatan  hasil_kmeans
# 0   -0.976078   0.642902             2
# 1   -0.031661   0.169167             1
# 2    0.067133  -0.925482             1
# 3   -0.181187  -1.532598             1
# 4    2.133795  -0.070000             0
# ..        ...        ...           ...
# 118 -0.330713  -0.428751             1
# 119  2.480908  -0.585129             0
# 120 -0.773951   0.302549             1
# 121 -0.773951  -0.460946             1
# 122 -0.733899  -0.134391             1
#
# [123 rows x 3 columns]

# %%
k1_x1 = df8.GDP[df8.hasil_kmeans == 0]
k1_y1 = df8.Kesehatan[df8.hasil_kmeans == 0]

k2_x1 = df8.GDP[df8.hasil_kmeans == 1]
k2_y1 = df8.Kesehatan[df8.hasil_kmeans == 1]

k3_x1 = df8.GDP[df8.hasil_kmeans == 2]
k3_y1 = df8.Kesehatan[df8.hasil_kmeans == 2]

#k4_x1 = df8.GDP[df8.hasil_kmeans == 3]
#k4_y1 = df8.Kesehatan[df8.hasil_kmeans == 3]

plt.subplots(figsize=(15,8))
plt.scatter(k1_x1, k1_y1, c='red', s=100, edgecolors='green', linestyle='-')
plt.scatter(k2_x1, k2_y1, c='blue', s=100, edgecolors='green', linestyle='-')
plt.scatter(k3_x1, k3_y1, c='yellow', s=100, edgecolors='green', linestyle='-')
#plt.scatter(k4_x1, k4_y1, c='purple', s=100, edgecolors='green', linestyle='-')

centers = kmeans2.cluster_centers_
plt.scatter(centers[:,0], centers[:,1], c='white', s=500)
plt.xlabel('GDP')
plt.ylabel('Kesehatan')
plt.show()

# %%
from sklearn.metrics import silhouette_score

print('Skor untuk 4 cluster: ', silhouette_score(df8, labels=labels))
print('Skor untuk 3 cluster: ', silhouette_score(df8, labels=labels2))
# Out:
# Skor untuk 4 cluster:  0.36247252298806687
# Skor untuk 3 cluster:  0.5532239930756935

# %% [markdown]
# ## Negara Mana Saja? ##

# %%
df6_normal
# Out:
#                   Negara  GDPperkapita  Kesehatan
# 0            Afghanistan           553       7.58
# 1                Albania          4090       6.55
# 2                Algeria          4460       4.17
# 3                 Angola          3530       2.85
# 4    Antigua and Barbuda         12200       6.03
# ..                   ...           ...        ...
# 162              Vanuatu          2970       5.25
# 163            Venezuela         13500       4.91
# 164              Vietnam          1310       6.84
# 165                Yemen          1310       5.18
# 166               Zambia          1460       5.89
#
# [123 rows x 3 columns]

# %%
df_6 = df6_normal.copy()
df_6 = df_6.reset_index(drop=True)
df_6.columns = ['Negara', 'GDPperkapita', 'health']
df_6
# Out:
#                   Negara  GDPperkapita  health
# 0            Afghanistan           553    7.58
# 1                Albania          4090    6.55
# 2                Algeria          4460    4.17
# 3                 Angola          3530    2.85
# 4    Antigua and Barbuda         12200    6.03
# ..                   ...           ...     ...
# 118              Vanuatu          2970    5.25
# 119            Venezuela         13500    4.91
# 120              Vietnam          1310    6.84
# 121                Yemen          1310    5.18
# 122               Zambia          1460    5.89
#
# [123 rows x 3 columns]

# %%
list_dataframe = [df_6, df8]
df_7 = pd.concat(list_dataframe, axis=1)

# %%
df_7
# Out:
#                   Negara  GDPperkapita  health       GDP  Kesehatan  \
# 0            Afghanistan           553    7.58 -0.976078   0.642902
# 1                Albania          4090    6.55 -0.031661   0.169167
# 2                Algeria          4460    4.17  0.067133  -0.925482
# 3                 Angola          3530    2.85 -0.181187  -1.532598
# 4    Antigua and Barbuda         12200    6.03  2.133795  -0.070000
# ..                   ...           ...     ...       ...        ...
# 118              Vanuatu          2970    5.25 -0.330713  -0.428751
# 119            Venezuela         13500    4.91  2.480908  -0.585129
# 120              Vietnam          1310    6.84 -0.773951   0.302549
# 121                Yemen          1310    5.18 -0.773951  -0.460946
# 122               Zambia          1460    5.89 -0.733899  -0.134391
#
#      hasil_kmeans
# 0               2
# 1               1
# 2               1
# 3               1
# 4               0
# ..            ...
# ...

# %%
kluster_0 = df_7['hasil_kmeans'] == 0
kluster_1 = df_7['hasil_kmeans'] == 1
kluster_2 = df_7['hasil_kmeans'] == 2

df_7_k0 = df_7[(kluster_0)]
df_7_k0
# Out:
#                   Negara  GDPperkapita  health       GDP  Kesehatan  \
# 4    Antigua and Barbuda         12200    6.03  2.133795  -0.070000
# 5              Argentina         10300    8.10  1.626474   0.882069
# 16                Brazil         11200    9.01  1.866784   1.300611
# 17              Bulgaria          6840    6.87  0.702618   0.316347
# 25                 Chile         12900    7.96  2.320702   0.817678
# 27              Colombia          6250    7.59  0.545082   0.647501
# 33               Croatia         13500    7.76  2.480908   0.725690
# 40                 Gabon          8750    3.50  1.212608  -1.233640
# 44               Grenada          7370    5.86  0.844133  -0.148189
# 50               Hungary         13100    7.33  2.374104   0.527917
# 53                  Iran          6530    5.60  0.619844  -0.267773
# 57            Kazakhstan          9070    4.29  1.298051  -0.870290
# 62                Latvia         11300    6.68  1.893485   0.228959
# ...

# %% [markdown]
# Ini merupakan kluster pertama, ditandai dengan warna merah pada scatter plot KMEAN, kluster ini bukan merupakan prioritas karena GDP tinggi

# %%
df_7_k1 = df_7[(kluster_1)]
df_7_k1
# Out:
#          Negara  GDPperkapita  health       GDP  Kesehatan  hasil_kmeans
# 1       Albania          4090    6.55 -0.031661   0.169167             1
# 2       Algeria          4460    4.17  0.067133  -0.925482             1
# 3        Angola          3530    2.85 -0.181187  -1.532598             1
# 6       Armenia          3220    4.40 -0.263961  -0.819697             1
# 7    Azerbaijan          5840    5.88  0.435607  -0.138991             1
# ..          ...           ...     ...       ...        ...           ...
# 117  Uzbekistan          1380    5.81 -0.755260  -0.171186             1
# 118     Vanuatu          2970    5.25 -0.330713  -0.428751             1
# 120     Vietnam          1310    6.84 -0.773951   0.302549             1
# 121       Yemen          1310    5.18 -0.773951  -0.460946             1
# 122      Zambia          1460    5.89 -0.733899  -0.134391             1
#
# [71 rows x 6 columns]

# %% [markdown]
# Ini merupakan cluster kedua yang merupakan cluster prioritas HELP, karena GDP nya rendah, dan tingkat kesehatan juga rendah

# %%
df_7_k2 = df_7[(kluster_2)]
df_7_k2
# Out:
#                      Negara  GDPperkapita  health       GDP  Kesehatan  \
# 0               Afghanistan           553    7.58 -0.976078   0.642902
# 14   Bosnia and Herzegovina          4610   11.10  0.107184   2.261878
# 15                 Botswana          6350    8.30  0.571783   0.974056
# 19                  Burundi           231   11.60 -1.062055   2.491847
# 29         Congo, Dem. Rep.           334    7.91 -1.034553   0.794681
# 31               Costa Rica          8200   10.90  1.065752   2.169891
# 35                  Ecuador          4660    8.06  0.120535   0.863671
# 42                  Georgia          2960   10.10 -0.333383   1.801942
# 47            Guinea-Bissau           547    8.50 -0.977680   1.066043
# 54                     Iraq          4500    8.41  0.077813   1.024649
# 56                   Jordan          3680    8.04 -0.141136   0.854472
# 59                 Kiribati          1490   11.30 -0.725889   2.353866
# ...

# %% [markdown]
# Ini merupakan kluster negara prioritas kedua HELP, yang lebih baik difokuskan memberi bantuan stimulus menggerakan kegiatan perekonomian, hal ini dikarenakan meskipun GDPnya rendah, kesadaran akan kesehatannya sudah tinggi

# %%
pd.options.display.max_rows
# Out:
# 60

# %%
pd.options.display.max_rows = 80
pd.options.display.max_rows
# Out:
# 80

# %%
df_7_k1
# Out:
#                              Negara  GDPperkapita  health       GDP  \
# 1                           Albania          4090    6.55 -0.031661
# 2                           Algeria          4460    4.17  0.067133
# 3                            Angola          3530    2.85 -0.181187
# 6                           Armenia          3220    4.40 -0.263961
# 7                        Azerbaijan          5840    5.88  0.435607
# 8                        Bangladesh           758    3.52 -0.921341
# 9                           Belarus          6030    5.61  0.486339
# 10                           Belize          4340    5.20  0.035091
# 11                            Benin           758    4.10 -0.921341
# 12                           Bhutan          2180    5.20 -0.541652
# 13                          Bolivia          1980    4.84 -0.595054
# 18                     Burkina Faso           575    6.74 -0.970204
# 20                         Cambodia           786    5.68 -0.913864
# ...

# %%
writer = pd.ExcelWriter('Kluster_2.xlsx')
df_7_k1.to_excel(writer)
writer.save()

# %%
df_7_k1[['Negara','GDPperkapita','health']].sort_values(by=['GDPperkapita', 'health']).head(10).reset_index(drop=True)
# Out:
#                      Negara  GDPperkapita  health
# 0                     Niger           348    5.16
# 1                Madagascar           413    3.77
# 2                Mozambique           419    5.21
# 3  Central African Republic           446    3.98
# 4                    Malawi           459    6.59
# 5                   Eritrea           482    2.66
# 6                    Gambia           562    5.69
# 7              Burkina Faso           575    6.74
# 8                     Nepal           592    5.25
# 9                    Guinea           648    4.93

# %% [markdown]
# Dengan demikian inilah 10 negara yang memiliki GDP terendah dan investasi kesehatan terendah.

# %%
df_7_k1[['Negara','GDPperkapita','health']].sort_values(by=['health']).head(10).reset_index(drop=True)
# Out:
#          Negara  GDPperkapita  health
# 0       Myanmar           988    1.97
# 1      Pakistan          1040    2.20
# 2   Congo, Rep.          2740    2.46
# 3  Turkmenistan          4440    2.50
# 4     Indonesia          3110    2.61
# 5       Eritrea           482    2.66
# 6        Angola          3530    2.85
# 7     Sri Lanka          2810    2.94
# 8    Bangladesh           758    3.52
# 9   Philippines          2130    3.61

# %% [markdown]
# ERITREA HARUS DIBERI PERHATIAN KHUSUS!!! GDP RENDAH, KESEHATAN JUGA RENDAH! HELP ERITREA
